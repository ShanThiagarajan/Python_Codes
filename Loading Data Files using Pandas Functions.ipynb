# %% [markdown]
# ## Loading various kinds of data files

# %%
import os 
os.getcwd()
# Out:
# 'F:\\Python Learning\\Imarticus'

# %%
## Let us load the required libraries
import pandas as pd

# %%
## Loading a csv file from the computer
df_cereal = pd.read_csv("../Sample_data/cereal.csv")

# %%
df_cereal.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
df_cereal['potass'].mean()
# Out:
# 96.07792207792208

# %%
## Identifying the missing values from the data file while loading the data itself.
df_cereal1 = pd.read_csv("../Sample_data/cereal.csv",na_values=[-1])

# %%
df_cereal1.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0     6.0   280.0        25      3     1.0  0.33  68.402973
# 1    8.0     8.0   135.0         0      3     1.0  1.00  33.983679
# 2    7.0     5.0   320.0        25      3     1.0  0.33  59.425505
# 3    8.0     0.0   330.0        25      3     1.0  0.50  93.704912
# 4   14.0     8.0     NaN        25      3     1.0  0.75  34.384843

# %%
df_cereal1.potass.mean()
# Out:
# 98.66666666666667

# %%
df_cereal2 = pd.read_csv("../Sample_data/cereal_2.csv",na_values=[-1])

# %%
df_cereal2.head()
# Out:
#                          X.1  X.2   X.3       X.4      X.5  X.6     X.7  \
# 0                       name  mfr  type  calories  protein  fat  sodium
# 1                  100% Bran    N     C        70        4    1     130
# 2          100% Natural Bran    Q     C       120        3    5      15
# 3                   All-Bran    K     C        70        4    1     260
# 4  All-Bran with Extra Fiber    K     C        50        4    0     140
#
#      X.8    X.9    X.10    X.11      X.12   X.13    X.14  X.15       X.16
# 0  fiber  carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 1     10      5       6     280        25      3       1  0.33  68.402973
# 2      2      8       8     135         0      3       1     1  33.983679
# 3      9      7       5     320        25      3       1  0.33  59.425505
# 4     14      8       0     330        25      3       1   0.5  93.704912

# %%
df_cereal2 = pd.read_csv("../Sample_data/cereal_2.csv",skiprows=1,na_values=[-1])
df_cereal2.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0     6.0   280.0        25      3     1.0  0.33  68.402973
# 1    8.0     8.0   135.0         0      3     1.0  1.00  33.983679
# 2    7.0     5.0   320.0        25      3     1.0  0.33  59.425505
# 3    8.0     0.0   330.0        25      3     1.0  0.50  93.704912
# 4   14.0     8.0     NaN        25      3     1.0  0.75  34.384843

# %%
df_txt = pd.read_csv("datasets/pandas/bigmarket.txt",sep='\t')
df_txt
# Out:
#     Month Store  Sales
# 0     Jan     A  31037
# 1     Jan     B  20722
# 2     Jan     C  24557
# 3     Jan     D  34649
# 4     Jan     E  29795
# 5     Feb     A  29133
# 6     Feb     B  22695
# 7     Feb     C  28312
# 8     Feb     D  31454
# 9     Feb     E  46267
# 10  March     A  32961
# 11  March     B  26451
# 12  March     C  47814
# 13  March     D  36069
# 14  March     E  31874
# 15    Apr     A  27253
# 16    Apr     B  40241
# 17    Apr     C  47488
# 18    Apr     D  25432
# 19    Apr     E  33880
# 20    May     A  29487
# 21    May     B  40001
# 22    May     C  46482
# 23    May     D  46313
# 24    May     E  47594

# %% [markdown]
# ## Loading the data from web

# %%
url='https://www1.ncdc.noaa.gov/pub/data/cdo/samples/PRECIP_HLY_sample_csv.csv'

df_url = pd.read_csv(url)
df_url.head()
# Out:
#        STATION     STATION_NAME  ELEVATION  LATITUDE  LONGITUDE  \
# 0  COOP:310301  ASHEVILLE NC US      682.1   35.5954   -82.5568
# 1  COOP:310301  ASHEVILLE NC US      682.1   35.5954   -82.5568
# 2  COOP:310301  ASHEVILLE NC US      682.1   35.5954   -82.5568
#
#              DATE   HPCP Measurement Flag Quality Flag
# 0  20100101 00:00  99999                ]
# 1  20100101 01:00      0                g
# 2  20100102 06:00      1

# %% [markdown]
# ## Loading the data from a JSON file

# %%
df_json = pd.read_json("datasets/pandas/bigmarket.json")
df_json.head()
# Out:
#   Month Store  Sales
# 0   Jan     A  31037
# 1   Jan     B  20722
# 2   Jan     C  24557
# 3   Jan     D  34649
# 4   Jan     E  29795

# %%
## Loading a data from excel file
df_excel = pd.read_excel("datasets/pandas/bigmarket.xlsx")
df_excel.head()
# Out:
#   Month Store  Sales
# 0   Jan     A  31037
# 1   Jan     B  20722
# 2   Jan     C  24557
# 3   Jan     D  34649
# 4   Jan     E  29795

# %%
## Loading a data from excel file for a specific sheet
df_order = pd.read_excel("datasets/pandas/customer1.xlsx",sheet_name="Order")
df_order.head()
# Out:
#    Order_ID  Cust_ID  Order
# 0       222      101    789
# 1       223      102    465
# 2       224      103    674
# 3       225      104    564

# %%
## Loading a data from excel file for a specific sheet
df_cust = pd.read_excel("datasets/pandas/customer1.xlsx")
df_cust.head()
# Out:
#    Cust_ID      Name
# 0      101    Olivia
# 1      102  Will LLC
# 2      103    Sophia
# 3      104  Isabella

# %%
## Loading multiple sheets from an excel file
files = pd.ExcelFile("datasets/pandas/customer1.xlsx")

# %%
print(files.sheet_names)
# Out:
# ['Cusotmer', 'Order']

# %%
df_cust = files.parse(sheet_name=0)
df_cust.head()
# Out:
#    Cust_ID      Name
# 0      101    Olivia
# 1      102  Will LLC
# 2      103    Sophia
# 3      104  Isabella
